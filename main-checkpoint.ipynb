# %% [markdown]
# # Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

import cv2
import tensorflow as tf
from tqdm import tqdm
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
class_names = ['building','forest','no changed','road','water']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %% [markdown]
# # Loading the Data
# We have to write a load_data function that load the images and the labels from the folder.

# %%
def load_data():

    datasets = ['C:/Users/LENOVO/Downloads/changes due to human activity/train', 'C:/Users/LENOVO/Downloads/changes due to human activity/test']

    output = []

    # Iterate through training and test sets
    for dataset in datasets:

        images = []
        labels = []

        print("Loading {}".format(dataset))

        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]

            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):

                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)

                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE)

                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)

        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')

        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading C:/Users/LENOVO/Downloads/changes due to human activity/train
# 100%|███████████████████████████████████████████████████████████████████████████████| 201/201 [00:00<00:00, 866.79it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 3917.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 52.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 50.78it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 103/103 [00:00<00:00, 3683.42it/s]
# Loading C:/Users/LENOVO/Downloads/changes due to human activity/test
# 100%|███████████████████████████████████████████████████████████████████████████████| 201/201 [00:00<00:00, 880.32it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 94/94 [00:00<00:00, 3921.90it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 53.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 52.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 103/103 [00:00<00:00, 3679.15it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 478
# Number of testing examples: 478
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts},
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0, 0,) ,
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """

    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """

    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %%
batch_size =15
epochs = 10
IMG_HEIGHT = 150
IMG_WIDTH = 150

# %%
cnn_model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(7, activation=tf.nn.softmax)
])
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
cnn_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = cnn_model.fit(train_images, train_labels, batch_size=128, epochs=30, validation_split = 0.2)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2749 - accuracy: 0.8586 - val_loss: 0.3992 - val_accuracy: 0.7812
# Epoch 2/30
# 3/3 [==============================] - 3s 941ms/step - loss: 0.2873 - accuracy: 0.8482 - val_loss: 0.4271 - val_accuracy: 0.7917
# Epoch 3/30
# 3/3 [==============================] - 3s 917ms/step - loss: 0.2754 - accuracy: 0.8560 - val_loss: 0.3786 - val_accuracy: 0.8125
# Epoch 4/30
# 3/3 [==============================] - 3s 910ms/step - loss: 0.2715 - accuracy: 0.8639 - val_loss: 0.3912 - val_accuracy: 0.8021
# Epoch 5/30
# 3/3 [==============================] - 3s 981ms/step - loss: 0.2423 - accuracy: 0.8848 - val_loss: 0.4357 - val_accuracy: 0.8125
# Epoch 6/30
# 3/3 [==============================] - 3s 940ms/step - loss: 0.2456 - accuracy: 0.8691 - val_loss: 0.3781 - val_accuracy: 0.8125
# Epoch 7/30
# 3/3 [==============================] - 3s 931ms/step - loss: 0.2404 - accuracy: 0.8927 - val_loss: 0.4159 - val_accuracy: 0.8021
# Epoch 8/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2457 - accuracy: 0.8691 - val_loss: 0.4248 - val_accuracy: 0.7812
# Epoch 9/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2515 - accuracy: 0.8639 - val_loss: 0.4717 - val_accuracy: 0.7500
# Epoch 10/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2687 - accuracy: 0.8482 - val_loss: 0.4665 - val_accuracy: 0.7604
# Epoch 11/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2472 - accuracy: 0.8691 - val_loss: 0.3995 - val_accuracy: 0.8021
# Epoch 12/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2382 - accuracy: 0.8770 - val_loss: 0.4180 - val_accuracy: 0.8021
# Epoch 13/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2250 - accuracy: 0.8848 - val_loss: 0.4408 - val_accuracy: 0.7812
# Epoch 14/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2295 - accuracy: 0.8822 - val_loss: 0.4026 - val_accuracy: 0.8125
# Epoch 15/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2444 - accuracy: 0.8822 - val_loss: 0.4319 - val_accuracy: 0.8229
# Epoch 16/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2302 - accuracy: 0.8770 - val_loss: 0.4078 - val_accuracy: 0.8021
# Epoch 17/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2272 - accuracy: 0.8770 - val_loss: 0.4623 - val_accuracy: 0.7917
# Epoch 18/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2449 - accuracy: 0.8822 - val_loss: 0.4634 - val_accuracy: 0.8021
# Epoch 19/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2277 - accuracy: 0.8874 - val_loss: 0.4115 - val_accuracy: 0.8021
# Epoch 20/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2232 - accuracy: 0.8848 - val_loss: 0.4347 - val_accuracy: 0.8125
# Epoch 21/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2134 - accuracy: 0.8953 - val_loss: 0.4346 - val_accuracy: 0.8125
# Epoch 22/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2063 - accuracy: 0.8979 - val_loss: 0.4080 - val_accuracy: 0.8021
# Epoch 23/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2092 - accuracy: 0.8953 - val_loss: 0.4402 - val_accuracy: 0.7917
# Epoch 24/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2075 - accuracy: 0.8901 - val_loss: 0.4323 - val_accuracy: 0.8125
# Epoch 25/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2037 - accuracy: 0.8901 - val_loss: 0.4406 - val_accuracy: 0.7917
# Epoch 26/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2195 - accuracy: 0.8586 - val_loss: 0.4813 - val_accuracy: 0.7812
# Epoch 27/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2253 - accuracy: 0.8613 - val_loss: 0.5051 - val_accuracy: 0.7188
# Epoch 28/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2371 - accuracy: 0.8560 - val_loss: 0.4567 - val_accuracy: 0.7812
# Epoch 29/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2206 - accuracy: 0.8639 - val_loss: 0.4413 - val_accuracy: 0.8125
# Epoch 30/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2032 - accuracy: 0.8874 - val_loss: 0.4468 - val_accuracy: 0.8125

# %%
test_loss = cnn_model.evaluate(test_images, test_labels)
# Out:
# 15/15 [==============================] - 1s 56ms/step - loss: 0.2384 - accuracy: 0.8808

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing import image
test_image = image.load_img('C:/Users/LENOVO/Downloads/changes due to human activity/no changed/9.jpg', target_size = (150, 150))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
predictions = cnn_model.predict(test_image)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability
print(pred_labels )
index = np.random.randint(test_image.shape[0])
plt.figure()
plt.imshow(test_image[index].astype('uint8'))
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.title('Change Detection Human Activity Output# {} : '.format(index) + class_names[pred_labels[index]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5 test_image = image.load_img('C:/Users/LENOVO/Downloads/changes due to human activity/no changed/9.jpg', target_size = (150, 150))
#       6 test_image = image.img_to_array(test_image)
# ----> 7 test_image = np.expand_dims(test_image, axis = 0)
#       8 predictions = cnn_model.predict(test_image)     # Vector of probabilities
#       9 pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability
#
# NameError: name 'np' is not defined
